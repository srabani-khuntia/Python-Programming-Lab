# %% [markdown]
# # ASSIGNMENT-8: DICTIONARIES

# %% [markdown]
# ## SRABANI KHUNTIA, 24BCSB03
# ## GROUP-E1, ROLL NO:7

# %% [markdown]
# #### 1. Create a dictionary containing the names of the winners of a competition as keys and number of their wins as values.

# %%
winners={'Jack':5, 'Michael':8, 'Fiona':5}
print(winners)
# Out:
# {'Jack': 5, 'Michael': 8, 'Fiona': 5}

# %% [markdown]
# #### 2. Create a phone directory of your friends and display it.

# %%
pd={'Jack':'9454843647', 'Michael':'8454684045', 'Fiona':'6371719945'}
print(pd)
# Out:
# {'Jack': '9454843647', 'Michael': '8454684045', 'Fiona': '6371719945'}

# %% [markdown]
# #### 3. Check whether a given key already exists in a dictionary or not.

# %%
winners={'Jack':5, 'Michael':8, 'Fiona':5}
key=input('Enter key to search: ')
print(key, ' exists.') if key in winners else print(key, ' does not exist.')
#Enter key to search:  John
# Out:
# Enter key to search:  John
# John  does not exist.

# %% [markdown]
# #### 4. Print a dictionary with the keys between 1 and 10 and its values are the square of the keys. [Output: {1: 1, 2: 4, 3: 9, 4: 16, ... }]

# %%
sq={i : i**2 for i in range(1,11)}
print(sq)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %% [markdown]
# #### 5. Merge two dictionaries.

# %%
d1={'Jack':5, 'Michael':8, 'Fiona':5}
d2={'John':5, 'Cyan':8, 'Mary':5}
d1.update(d2)
print(d1)
# Out:
# {'Jack': 5, 'Michael': 8, 'Fiona': 5, 'John': 5, 'Cyan': 8, 'Mary': 5}

# %% [markdown]
# #### 6. Add all the values present in a dictionary and show the total result.

# %%
d={'Jack': 5, 'Michael': 8, 'Fiona': 5, 'John': 5, 'Cyan': 8, 'Mary': 5}
print('Sum of all values: ', sum(d.values()))
# Out:
# Sum of all values:  36

# %% [markdown]
# #### 7. Multiply all the values present in a dictionary and display the final result.

# %%
d={'Jack': 5, 'Michael': 8, 'Fiona': 5, 'John': 5, 'Cyan': 8, 'Mary': 5}
p=1
for i in d:
    p*=d.get(i)
print('Product of all values: ', p)
# Out:
# Product of all values:  40000

# %% [markdown]
# #### 8. Remove a key from a dictionary.

# %%
d={'Jack': 5, 'Michael': 8, 'Fiona': 5, 'John': 5, 'Cyan': 8, 'Mary': 5}
key=input('Enter key to remove: ')
print(d.pop(key, 'Key does not exist'))
print(d)
# Enter key to remove:  56
# Out:
# Enter key to remove:  45
# Key does not exist
# {'Jack': 5, 'Michael': 8, 'Fiona': 5, 'John': 5, 'Cyan': 8, 'Mary': 5}

# %% [markdown]
# #### 9. Print a dictionary one line after the other. [Input: {‘SAI‘ : {'class‘ : 'VI', 'roll‘ : 8}, 'PRIYA': {'class‘ : 'V', 'roll’ : 3}}
# #### Output: SAI
# #### class : VI
# #### roll : 8
# #### PRIYA
# #### class : V
# #### roll : 3

# %%
d={'SAI':{'class':'VI', 'roll':8}, 
  'PRIYA': {'class':'V', 'roll':3}}
for name, info in d.items():
    print(name)
    for cls, roll in info.items():
        print(f"{cls} : {roll}")
# Out:
# SAI
# class : VI
# roll : 8
# PRIYA
# class : V
# roll : 3

# %% [markdown]
# #### 10. Create a nested dictionary containing the employee ID, name and designation of three employees and the then add a fourth employee as a new dictionary with his 1name, designation and salary. Display the old and new dictionary and finally remove the third employee and display the collection.

# %%
emp={1:{'Empid': 52652, 'Name': 'Srabani', 'Desgn': 'Manager'},
     2:{'Empid': 52656, 'Name': 'Sonia', 'Desgn': 'Accountant'},
     3:{'Empid': 52651, 'Name': 'Sam', 'Desgn': 'Deputy Manager'}
    }
d={4:{'Empid': 52653, 'Name': 'Sejal', 'Desgn': 'Clerk'}}
emp.update(d)
emp.pop(3)
print(emp)
# Out:
# {1: {'Empid': 52652, 'Name': 'Srabani', 'Desgn': 'Manager'}, 2: {'Empid': 52656, 'Name': 'Sonia', 'Desgn': 'Accountant'}, 4: {'Empid': 52653, 'Name': 'Sejal', 'Desgn': 'Clerk'}}

# %% [markdown]
# #### 11.  Count and display frequency of a word that appears in a given string. [Hint: take an empty dictionary, use split() to identify each words of string.]

# %%
d={}
s=input('Enter String: ')
l=s.split()
st=set(l)
for i in st:
    d[i]=l.count(i)
print(d)
#Enter String: hello hello hello i am am srabani
# Out:
# Enter String:  hello hello hello i am am srabani
# {'am': 2, 'hello': 3, 'i': 1, 'srabani': 1}

# %% [markdown]
# #### 12. Create a dictionary whose keys are month names and whose values are the number of days in the corresponding months.
# #### a) Ask the user to enter a month name and use the dictionary to tell how many days are there in that month.
# #### b) Print all of the keys in alphabetical order.
# #### c) Print all of the month with 31 days.

# %%
months={'January':31, 'February':28, 'March':31, 'April':30, 'May':31, 'June':30, 'July':31, 'August':31, 'September':30, 'October':31, 'November':30, 'December':31}

#(a)
m=input('Enter month: ')
print(f'{m.title()} has {months.get(m.title())} days.')

#(b)
print('Keys in alphabetical Order: ', sorted(months.keys()))

#(c)
m31=[]
for i in months:
    if months[i]==31:
        m31.append(i)
print('Months with 31 days are: ', m31 )
#Enter month: july
# Out:
# Enter month:  july
# July has 31 days.
# Keys in alphabetical Order:  ['April', 'August', 'December', 'February', 'January', 'July', 'June', 'March', 'May', 'November', 'October', 'September']
# Months with 31 days are:  ['January', 'March', 'May', 'July', 'August', 'October', 'December']

# %% [markdown]
# #### 13. Repeatedly ask the user to enter a team name and how many games the team has won and how many they lost. Store this information in a dictionary whose keys are the team names and the values are list of the form [wins, losses]. Perform the following using this dictionary:
# #### a) Enter any team name and print the team's winning percentage.
# #### b) Create a list whose entries are the number of wins of each team.

# %%
d={}
ans='y'
while(ans=='y'):
    name=input('Enter team name:')
    wins=int(input('Enter number of wins:'))
    losses=int(input('Enter number of losses:'))
    l=[wins, losses]
    d[name]=l
    ans=input('Anymore?(y/n):')

#(a)
t=input('Enter team name: ')
l=d.get(t)
win_pt=l[0]/sum(l) * 100
print(f'Wins % of team {t} is {win_pt}%')

#(b)
wins_list=[i[0] for i in d.values()] #(id.values())[0]
print('List of wins: ', wins_list)
# Out:
# Enter team name:titanic
# Enter number of wins:7
# Enter number of losses:6
# Anymore?(y/n):y
# Enter team name:losers
# Enter number of wins:7
# Enter number of losses:1
# Anymore?(y/n):y
# Enter team name:players
# Enter number of wins:7
# Enter number of losses:5
# Anymore?(y/n):n
# Enter team name: losers
# Wins % of team losers is 87.5%
# List of wins:  [7, 7, 7]

# %% [raw]
# Enter team name:titanic
# Enter number of wins:7
# Enter number of losses:6
# Anymore?(y/n):y
# Enter team name:losers
# Enter number of wins:7
# Enter number of losses:1
# Anymore?(y/n):y
# Enter team name:players
# Enter number of wins:7
# Enter number of losses:5
# Anymore?(y/n):n
# Enter team name: losers
# Wins % of team losers is 87.5%
# List of wins:  [7, 7, 7]
